# %%
from astropy.utils.data import get_pkg_data_filename
from astropy.io import fits
import astropy.coordinates as coord
import astropy.units as u
import numpy as np
from astropy import units as u
import matplotlib.pyplot as plt
from astropy.visualization import astropy_mpl_style
plt.style.use(astropy_mpl_style)
from astropy.time import Time
from astropy.coordinates import SkyCoord, EarthLocation, FK5
from astropy.coordinates import AltAz
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
matplotlib.axes.Axes.imshow
matplotlib.pyplot.imshow
matplotlib.figure.Figure.colorbar
matplotlib.pyplot.colorbar
matplotlib.colors.BoundaryNorm
matplotlib.colorbar.ColorbarBase.set_label
import matplotlib.colors as colors
from astropy.wcs import WCS

filename = get_pkg_data_filename('ACE_allSB_2min_SUBTRACTED_CORRECTED_MODEL_DATA_test-image.fits')
hdu = fits.open(filename)[0]
wcs = WCS(hdu.header)
image_data = hdu.data

fig = plt.figure()
#fig.add_subplot(111, projection=wcs, slices=('x', 'y', 0, 0))
plt.imshow(image_data[0, 0, :, :], cmap='viridis', origin='left')
plt.grid(False)
#plt.clim(-85492.31, 131706.03)
#plt.clim(-31226.89, 38757.72)
plt.clim(-6.39, 36.78)
plt.colorbar(extend='both', label='Jy/beam')
plt.axis('off')
plt.xlabel('RA')
plt.title(r'The radio sky above LOFAR on' '\n' '2018-11-07 at 19:55:09.3')
plt.show()
plt.savefig('fullSKy.png', dpi=200)

# %%
from astropy.utils.data import get_pkg_data_filename
from astropy.io import fits
import astropy.coordinates as coord
import astropy.units as u
import numpy as np
from astropy import units as u
import matplotlib.pyplot as plt
from astropy.visualization import astropy_mpl_style
plt.style.use(astropy_mpl_style)
from astropy.time import Time
from astropy.coordinates import SkyCoord, EarthLocation, FK5
from astropy.coordinates import AltAz
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
matplotlib.axes.Axes.imshow
matplotlib.pyplot.imshow
matplotlib.figure.Figure.colorbar
matplotlib.pyplot.colorbar
matplotlib.colors.BoundaryNorm
matplotlib.colorbar.ColorbarBase.set_label
import matplotlib.colors as colors
from astropy.wcs import WCS

filename = get_pkg_data_filename('ACE_allSB_2min_SUBTRACTED_CORRECTED_MODEL_DATA_test-image.fits')
hdu = fits.open(filename)[0]
plt.figure()
plt.imshow(hdu.data[0, 0, :, :], cmap='viridis', origin='left')
plt.grid(False)
#plt.clim(-31226.89, 38757.72)
#plt.clim(-11.88,36.48)
plt.clim(-6.39, 36.78)
#plt.colorbar(extend='both', label='Jy/beam')
plt.axis('off')
plt.show()
plt.savefig('fullSKy_model.png', dpi=600)

# %% [markdown]
# THE FOLLOWING ARE THE INDECES OF THE SOURCES FOUND BY PYBDSF IN PLACE OF CAS AND CYGNUS. THEY MUST BE IGNORED.
# DO NOT DELETE THE BELOW!

# %%
import astropy.coordinates as coord
import astropy.units as u
import numpy as np
from astropy import units as u
import matplotlib.pyplot as plt
from astropy.visualization import astropy_mpl_style
plt.style.use(astropy_mpl_style)
from astropy.time import Time
from astropy.coordinates import SkyCoord, EarthLocation, FK5
from astropy.coordinates import AltAz
import numpy as np
import matplotlib.pyplot as plt

f = open("sourcesExtracted_uvCut.ascii", "r")
f.readline()
f.readline()
f.readline()
f.readline()
f.readline()
f.readline()

Ra1=[]
Dec1=[]

for line in f:
    if 'nan'in line:
        continue
    ra = line.strip().split()[2]
    Ra1.append(float(ra))
    dec = line.strip().split()[4]
    Dec1.append(float(dec))

#keep this list of ra and dec to be discarded
#not the index but the actual number
discard=[138, 137, 125, 124, 123, 122, 121, 119, 118] # all fake sources in CygA plus the galaxy


for i in discard:
   #print(Ra1[i])
    print(Dec1[i])
    #ec1.pop(i)
    #a1.pop(i)

newf=open("ExtractedSources_woCYG_and_galaxy.ann", "w")
newf.write("COLOR GREEN \nPA SKY\n")
for i,j in zip(Ra1, Dec1):
    newf.write("CIRCLE %3.2f %3.2f 1 \n"%(i, j))
newf.close()
